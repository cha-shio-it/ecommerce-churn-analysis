# %%
import pandas as pd

# 定义策略数据
strategies = [
    {
        "优先级": "P0",
        "策略ID": "S1",
        "目标用户群": "多客服用户",
        "用户特征": "客服咨询次数处于前 33% 分位",
        "干预措施": "客服主动外呼回访 + 限时免邮券 + 专属折扣码 + 优化结算流程",
        "预期效果": "平均流失率降至 30% 以内"
    },
    {
        "优先级": "P0",
        "策略ID": "S2",
        "目标用户群": "低频用户",
        "用户特征": "购买总次数处于后 33% 分位",
        "干预措施": "新用户欢迎礼包（满减+运费券）+ 7 天连续签到奖励 + 推送爆款商品",
        "预期效果": "流失率从 38%–41% 降至 25% 左右"
    },
    {
        "优先级": "P0",
        "策略ID": "S3",
        "目标用户群": "高弃购 + 中客服",
        "用户特征": "弃购率处于前 33% 且客服次数处于中 33%",
        "干预措施": "分析客服会话定位高频问题 + 推送专属优惠与个性化商品推荐 + 购物车降价提醒",
        "预期效果": "流失率从 47% 降至 30%"
    },
    {
        "优先级": "P1",
        "策略ID": "S4",
        "目标用户群": "中/高频 + 高客单价用户",
        "用户特征": "购买频次中/高 且 客单价前 33%",
        "干预措施": "高价值用户俱乐部（VIP折扣、新品优先购）+ 专属客服通道 + 生日礼遇",
        "预期效果": "流失率从 35%–37% 降至 20% 以下"
    },
    {
        "优先级": "P1",
        "策略ID": "S5",
        "目标用户群": "高弃购 + 少客服",
        "用户特征": "弃购率前 33% 且 客服次数后 33%",
        "干预措施": "购物车降价提醒 + 限时优惠码（24h有效）+ 展示相似商品",
        "预期效果": "弃购率降低 20%，转化率提升 10%"
    },
    {
        "优先级": "P1",
        "策略ID": "S6",
        "目标用户群": "低弃购 + 中客服",
        "用户特征": "弃购率后 33% 且 客服次数中 33%",
        "干预措施": "客服回访了解潜在障碍 + 提供针对性补偿（运费险、价格保护） + 优化商品页评价",
        "预期效果": "流失率从 33% 降至 20%"
    },
    {
        "优先级": "P2",
        "策略ID": "S7",
        "目标用户群": "中/高频 + 中客单价",
        "用户特征": "购买频次中/高 且 客单价中 33%",
        "干预措施": "向上销售推荐（稍高客单价关联商品）+ 会员等级升级提醒",
        "预期效果": "平均客单价提升 10%，长期留存率提高"
    },
    {
        "优先级": "P2",
        "策略ID": "S8",
        "目标用户群": "所有用户",
        "用户特征": "全局优化",
        "干预措施": "定期分析弃购原因 + 优化客服知识库 + 建立流失预警机制",
        "预期效果": "全量用户季度流失率逐步降低 5%–10%"
    }
]

# 转换为 DataFrame
strategy_df = pd.DataFrame(strategies)
print(strategy_df)

# 保存到 CSV
strategy_df.to_csv('../outputs/strategy_table.csv', index=False, encoding='utf-8-sig')
print("策略表已保存到 ../outputs/strategy_table.csv")
# Out:
#   优先级 策略ID          目标用户群                     用户特征  \
# 0  P0   S1          多客服用户         客服咨询次数处于前 33% 分位
# 1  P0   S2           低频用户          购买总次数处于后 33% 分位
# 2  P0   S3      高弃购 + 中客服  弃购率处于前 33% 且客服次数处于中 33%
# 3  P1   S4  中/高频 + 高客单价用户       购买频次中/高 且 客单价前 33%
# 4  P1   S5      高弃购 + 少客服     弃购率前 33% 且 客服次数后 33%
# 5  P1   S6      低弃购 + 中客服     弃购率后 33% 且 客服次数中 33%
# 6  P2   S7    中/高频 + 中客单价       购买频次中/高 且 客单价中 33%
# 7  P2   S8           所有用户                     全局优化
#
#                                        干预措施                    预期效果
# 0         客服主动外呼回访 + 限时免邮券 + 专属折扣码 + 优化结算流程          平均流失率降至 30% 以内
# 1       新用户欢迎礼包（满减+运费券）+ 7 天连续签到奖励 + 推送爆款商品  流失率从 38%–41% 降至 25% 左右
# 2   分析客服会话定位高频问题 + 推送专属优惠与个性化商品推荐 + 购物车降价提醒         流失率从 47% 降至 30%
# 3      高价值用户俱乐部（VIP折扣、新品优先购）+ 专属客服通道 + 生日礼遇  流失率从 35%–37% 降至 20% 以下
# 4            购物车降价提醒 + 限时优惠码（24h有效）+ 展示相似商品     弃购率降低 20%，转化率提升 10%
# 5  客服回访了解潜在障碍 + 提供针对性补偿（运费险、价格保护） + 优化商品页评价         流失率从 33% 降至 20%
# ...
